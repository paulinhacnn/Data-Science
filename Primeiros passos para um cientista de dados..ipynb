# %% [markdown]
# # Primeiro passo: Estatística Descritiva

# %% [markdown]
# ## O que é estatística?
#
# É o ramo do conhecimento que explora a coleta, a organização, análise e a interpretação de dados.

# %% [markdown]
# Método Científico:
# ==========
#
# Conjunto de estratégias, ferramentas e ideias resultantes da experiência humana e consequentes do acúmulo de saberes, que estruturadas e sistematizadas, possibilitam alcançar um objetivo, que é responder a uma pergunta.

# %% [markdown]
# Toda pesquisa científica seja no âmbito acadêmico ou empresarial se inicia com uma pergunta. São exemplos:
# =====================================================================================================================
#
# **Negócio**
#
# * Qual o número de inadiplentes na bandeira mastercard de cartão de crédito?
#
# **Saúde**
#
# * Qual a prevalência de câncer de mama?
#
# **Direito**
#
# * Quantas ações trabalhistas existem no Brasil?
#
# **Comunidade**
#
# * Em um grupo de 900 programadores quantos bebem café e quantos não bebem café?
#
#
# Todas essas perguntas seguem o mesmo fluxo, como mostra a figura abaixo:

# %%
from IPython.display import Image
Image(filename='estatistica.png')

# %% [markdown]
# ***Depois de organizarmos a nossa pergunta, o primeiro passo é entender o que é uma variável***

# %% [markdown]
# # Variável:

# %% [markdown]
# **Variável** é uma característica de interesse que pode assumir diferentes valores ou classificações para diferentes sujeitos.
#
# * Muitas pessoas podem ler isso e dizer e daí, o que isso significa?
# * Em qual etapa eu identifico as minhas variáveis?
#
# **Então vamos primeiro organizar essas perguntas:**
#
# 1. A variável nada mais e do que um atributo, uma característica de uma pessoa ou coisa.
#
#    Para ficar mais clara essa ideia, vamos observar as nossas perguntas anteriores.
#
#    1.1 Qual o número de inadiplentes na bandeira mastercard cartão de crédito?
#
#    Vamos analisar com cuidado, vamos fazer por exclusão de palavras:
#      1.1.1 o pronome relativo(qual) e as preposições (o, de, na), posso garantir que não são variáveis,            elas somente compõe a frase para não ficar esquisito o texto.
#
#       Bom agora temos:
#
#       * número inadiplentes
#
#       * bandeira mastercard cartão crédito
#
#       Agora sim, vamos pensar um pouco ....
#
#       É o **número de inadiplentes** ela será a minha variável \0/
#
#       A bandeira mastercard cartão crédito, está ligado ao negócio da empresa neste caso, ou seja, trabalho na mastercard e que saber o nicho que quero focar dentre todos os dados que tenho, pois imagine se eu pesquisar todos os inadiplentes do Brasil, vai aparecer todas as bandeiras de cartões de crédito, carne das casas bahia, enfim vc vai passar a vida tentando encontrar esse dado, visto que todo dia alguem esquece de pagar uma conta.
#
#       Vamos ver mais um exemplo
#
#       Qual a prevalência de câncer de mama no Brasil?
#
#       Agora está mais fácil, separando da mesma forma que o exemplo anterior, temos:
#
#       * prevalência cancer mama
#
#       * Brasil
#
#       Temos que prevalência **câncer mama** será a minha variável \0/
#
#       1.1.2 Outra pergunta feita e em que momento eu identifico a(s) minha(s) variável(is), também posso te assegurar antes da coleta de dados, pois se não vc vai parecer uma barata tonta no meio de tanta informação e nunca conseguirá planejar o seu projeto e/ou produto \0/ (Iupi).

# %% [markdown]
# Bom agora que entendemos na frase o que é uma variável vamos classificá-la, pois precisamos entender a sua natureza para que assim no futuro, nao façamos alguma mer.... muito grande e estrague o projeto =).
# ============
#
#
#    As variáveis podem ser classificadas como ***qualitativas e quantitativas***, e cada uma delas tem mais duas divisões, mas vamos por partes.
#
# Vamos focar nas perguntas triviais:
#
# O que e uma **variável quantitativa**?
#
# São as características que podem ser descritas por números, ou seja, apresentam valores númericos.
#
#
# Aqui o mais importante é entender que **quantitativo = valores numéricos** \o/ (Iupi).
#
# Como disse antes a variável quantitativa apresenta duas subdivisões:
#
#
# ***variáveis discretas***: seus possíveis valores pertencem a um conjunto finito ou contável, ou seja, resumindo são números inteiros (lembre-se da matematica numeros naturais N = {1, 2, 3, 4, 5, ....}). Também podemos dizer que são resultados de contagens.
#
# Exemplos: Número de clientes na empresa, Número de bacterias em uma placa de petri, numero de pessoas que bebem café, Número de inadiplentes ...
#
#
# ***variáveis contínuas***: assumem valores em uma escala contínua (na reta real), na matemática números decimais , nossa que tédio, vamos simplificar.
#
# Podemos pensar que se temos números decimais precisamos de um instrumento de medida, como: balança -> peso, régua -> altura, relogio -> tempo, e assim por diante.
#
#
#
#
# O que é uma ***variável qualitativa***?
#
# Sao características que não possuem valores quantitativos e são definidas por categorias, ou seja, representam uma classificacão dos indivíduos.
#
# Eita nóis, parece um blá blá blá que ninguém entende, mas vamos tornar essa frase um pouco mais simples. Para que fique mais clara está explicação, iremos dividir em duas subdivisões.
#
#
# ***variáveis nominais***: não existe ordenação dentre as categorias. Exemplos:fumante/não fumante, doente/sadio, sexo.
#
#
# ***variáveis ordinais***: existe uma ordenação entre as categorias.
#
# Exemplos: Santander - categorias por renda (Pessoa Física, Van Gogh, Select, Private Banking) , estágio da doença (inicial, intermediário, terminal).

# %% [markdown]
# Diga quais variáveis abaixo são discretas e quais são contínuas:
# a)  População: alunos de uma cidade
# 	variável: cor dos olhos
# 	variável: altura
# 	variável: peso
# 	variável: nome
#
# b) População: Pregos produzidos por uma máquina
# 	variável: número de pregos produzidos
# 	variável: comprimento dos pregos
# 	variável: número de pregos defeituosos
# 	variável: diâmetro do prego

# %% [markdown]
# ***Proxima semana teremos outro tópico e as respostas***

# %% [markdown]
# ## Curiosidade: Uso de variáveis quantitativas e qualitativas em machine learning

# %% [markdown]
# Os conceitos de variáveis é de suma importância tanto em aprendizado de máquina quanto na estatística, quando entendemos essa característica, além de utilizarmos as ferramentas corretas para classificação, também conseguimos interpretar a saída o qual é nos dada. Pensando no contexto univariado, tanto em Aprendizado de Máquina quanto na Estatística em geral, a análise são específicas à classe da variável resposta.
#
# Então podemos descrever, como:
#
# Para variáveis quantitativas (contínuas ou discretas)podemos ter interesse em predizer o valor da variável para uma nova observação não presente na amostra.
#
# Ex: o preço de uma ação do mercado financeiro.
#
# Agora quando pensamos em variáveis qualitativas o interesse está na classificação de novas observações nas classes da variável em estudo.
#
# Ex.: classificar o estado de uma doença.

# %% [markdown]
# Material de apoio:
# =================
#
# https://www.ime.unicamp.br/~veronica/Coordenadas1s/aula1.pdf
#
# http://www.scielo.br/pdf/ptp/v22n2/a10v22n2.pdf
#
# https://www.youtube.com/watch?v=1zy6DTHQDzM
